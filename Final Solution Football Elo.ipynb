# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
#Germany League
url = 'http://clubelo.com/GER/Ranking'

r = requests.get(url)
html = r.text

soup = BeautifulSoup(html)
table = soup.find('table', {"class": "ranking"})
rows = table.find_all('tr')
data = []
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

germany = pd.DataFrame(data, columns=['Rank', 'Club', 'Elo', 'Last Match', 'Coach'])

# %%
for i in range(20,36):
    germany = germany.drop(i)

# %%
germany
# Out:
#    Rank             Club   Elo  Last Match  \
# 0     1         1 Bayern  2010  2020-06-27
# 1     2    10 RB Leipzig  1845  2020-06-27
# 2     3      12 Dortmund  1834  2020-06-27
# 3     4    18 Leverkusen  1795  2020-06-27
# 4     5      23 Gladbach  1760  2020-06-27
# 5     6    35 Hoffenheim  1730  2020-06-27
# 6     7     41 Wolfsburg  1718  2020-06-27
# 7     8     44 Frankfurt  1706  2020-06-27
# 8     9      60 Freiburg  1661  2020-06-27
# 9    10         64 Mainz  1653  2020-06-27
# 10   11        66 Hertha  1649  2020-06-27
# 11   12        76 Werder  1632  2020-07-06
# 12   13       86 Schalke  1608  2020-06-27
# 13   14      90 Augsburg  1605  2020-06-27
# 14   15  95 Union Berlin  1600  2020-06-27
# 15   16          96 Köln  1600  2020-06-27
# 16   17    100 Bielefeld  1595  2020-06-28
# 17   18       Düsseldorf  1592  2020-06-27
# 18   19        Stuttgart  1566  2020-06-28
#
#                                       Coach
# 0            Hansi Flick (since 2019-11-03)
# ...

# %%
def prob_of_winning(elo_differential):
    m=(-elo_differential)/400
    return 1/(1+10**m)
def int_ratio(elo_diff):
    proba=prob_of_winning(elo_diff)
    proba=proba*100
    proba=int(proba)
    return str(proba)+"%"
def str_to_int(c):
    ch=""
    for e in c:
        if(e=='0' or e=='1' or e=='2' or e=='3' or e=='4' or e=='5' or e=='6' or e=='7' or e=='8' or e=='9' ):
            ch=ch+e
    return int(ch)

# %%
str_to_int("5%")
# Out:
# 5

# %%
Home_team=input("Enter the Home Team ")
Away_team=input("Enter the Away Team ")
Team1=germany[germany['Club']==Home_team]['Elo'].values
Team2=germany[result['Club']==Away_team]['Elo'].values
team1_elo=int(Team1)+50 #Home Team has advantage
team2_elo=int(Team2)
elo_diff=team1_elo-team2_elo
print("the probability for",Home_team,"to win is: ",int_ratio(elo_diff))
print("the probability for",Away_team,"to win is: ",int_ratio(-elo_diff))
a=str_to_int(int_ratio(elo_diff))
b=str_to_int(int_ratio(-elo_diff))

print("the probability to Draw is :",str(c)+"%")
# Out:
# Enter the Home Team 1 Bayern
# Enter the Away Team Stuttgart
# the probability for 1 Bayern to win is:  94%
# the probability for Stuttgart to win is:  5%
# the probability to Draw is : 1%
# C:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
#English Premier LEague
import pandas as pd
import requests
from bs4 import BeautifulSoup
#Germany League
url = 'http://clubelo.com/ENG/Ranking'

r = requests.get(url)
html = r.text

soup = BeautifulSoup(html)
table = soup.find('table', {"class": "ranking"})
rows = table.find_all('tr')
data = []
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

england = pd.DataFrame(data, columns=['Rank', 'Club', 'Elo', 'Last Match', 'Coach'])

# %%
england
# Out:
#    Rank                 Club   Elo  Last Match  \
# 0     1          2 Liverpool  1995  2020-07-26
# 1     2           3 Man City  1989  2020-07-26
# 2     3         8 Man United  1876  2020-07-26
# 3     4           14 Chelsea  1824  2020-07-26
# 4     5         15 Tottenham  1809  2020-07-26
# 5     6           16 Arsenal  1803  2020-07-26
# 6     7            19 Wolves  1783  2020-07-26
# 7     8         22 Leicester  1762  2020-07-26
# 8     9           36 Burnley  1727  2020-07-26
# 9    10       37 Southampton  1725  2020-07-26
# 10   11           39 Everton  1720  2020-07-26
# 11   12  46 Sheffield United  1698  2020-07-26
# 12   13          49 West Ham  1690  2020-07-26
# 13   14         52 Newcastle  1682  2020-07-26
# 14   15    54 Crystal Palace  1678  2020-07-26
# 15   16          61 Brighton  1658  2020-07-26
# 16   17           65 Watford  1650  2020-07-26
# 17   18       74 Bournemouth  1634  2020-07-26
# 18   19             77 Leeds  1629  2020-07-22
# ...

# %%
for i in range(21,44):
    england = england.drop(i)

# %%
england
# Out:
#    Rank                 Club   Elo  Last Match  \
# 0     1          2 Liverpool  1995  2020-07-26
# 1     2           3 Man City  1989  2020-07-26
# 2     3         8 Man United  1876  2020-07-26
# 3     4           14 Chelsea  1824  2020-07-26
# 4     5         15 Tottenham  1809  2020-07-26
# 5     6           16 Arsenal  1803  2020-07-26
# 6     7            19 Wolves  1783  2020-07-26
# 7     8         22 Leicester  1762  2020-07-26
# 8     9           36 Burnley  1727  2020-07-26
# 9    10       37 Southampton  1725  2020-07-26
# 10   11           39 Everton  1720  2020-07-26
# 11   12  46 Sheffield United  1698  2020-07-26
# 12   13          49 West Ham  1690  2020-07-26
# 13   14         52 Newcastle  1682  2020-07-26
# 14   15    54 Crystal Palace  1678  2020-07-26
# 15   16          61 Brighton  1658  2020-07-26
# 16   17           65 Watford  1650  2020-07-26
# 17   18       74 Bournemouth  1634  2020-07-26
# 18   19             77 Leeds  1629  2020-07-22
# ...

# %%
Home_team=input("Enter the Home Team ")
Away_team=input("Enter the Away Team ")
Team1=england[england['Club']==Home_team]['Elo'].values
Team2=england[england['Club']==Away_team]['Elo'].values
team1_elo=int(Team1)+50 #Home Team has advantage
team2_elo=int(Team2)
elo_diff=team1_elo-team2_elo
print("the probability for",Home_team,"to win is: ",int_ratio(elo_diff))
print("the probability for",Away_team,"to win is: ",int_ratio(-elo_diff))
a=str_to_int(int_ratio(elo_diff))
b=str_to_int(int_ratio(-elo_diff))

print("the probability to Draw is :",1-prob_of_winning(team1_elo-team2_elo)-prob_of_winning(team2_elo-team1_elo))
# Out:
# Enter the Home Team 61 Brighton
# Enter the Away Team 39 Everton
# the probability for 61 Brighton to win is:  48%
# the probability for 39 Everton to win is:  51%
# the probability to Draw is : 0.0

# %%
##Spanish LIGA
import pandas as pd
import requests
from bs4 import BeautifulSoup
#Germany League
url = 'http://clubelo.com/ESP/Ranking'

r = requests.get(url)
html = r.text

soup = BeautifulSoup(html)
table = soup.find('table', {"class": "ranking"})
rows = table.find_all('tr')
data = []
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

spain = pd.DataFrame(data, columns=['Rank', 'Club', 'Elo', 'Last Match', 'Coach'])

# %%
for i in range(21,42):
    spain = spain.drop(i)

# %%
spain
# Out:
#    Rank              Club   Elo  Last Match  \
# 0     1       4 Barcelona  1964  2020-07-19
# 1     2     5 Real Madrid  1921  2020-07-19
# 2     3        6 Atlético  1898  2020-07-19
# 3     4        13 Sevilla  1827  2020-07-19
# 4     5     20 Villarreal  1771  2020-07-19
# 5     6         28 Getafe  1745  2020-07-19
# 6     7  30 Real Sociedad  1740  2020-07-19
# 7     8       34 Valencia  1733  2020-07-19
# 8     9         38 Bilbao  1720  2020-07-19
# 9    10        43 Granada  1714  2020-07-19
# 10   11        45 Levante  1698  2020-07-19
# 11   12        47 Osasuna  1696  2020-07-19
# 12   13          50 Eibar  1684  2020-07-19
# 13   14          55 Celta  1669  2020-07-19
# 14   15          56 Betis  1666  2020-07-19
# 15   16        58 Leganes  1664  2020-07-19
# 16   17     63 Valladolid  1654  2020-07-19
# 17   18         71 Alavés  1642  2020-07-19
# 18   19       87 Espanyol  1608  2020-07-19
# 19   20       93 Mallorca  1604  2020-07-19
# ...

# %%
Home_team=input("Enter the Home Team ")
Away_team=input("Enter the Away Team ")
Team1=spain[spain['Club']==Home_team]['Elo'].values
Team2=spain[spain['Club']==Away_team]['Elo'].values
team1_elo=int(Team1)+75 #Home Team has advantage
team2_elo=int(Team2)
elo_diff=team1_elo-team2_elo

print("the probability for",Home_team,"to win is: ",prob_of_winning(elo_diff))
print("the probability for",Away_team,"to win is: ",prob_of_winning(-elo_diff))
# Out:
# Enter the Home Team Huesca
# Enter the Away Team 56 Betis
# the probability for Huesca to win is:  0.39646368147382194
# the probability for 56 Betis to win is:  0.6035363185261781

# %%
##League 1 france
import pandas as pd
import requests
from bs4 import BeautifulSoup
#Germany League
url = 'http://clubelo.com/FRA/Ranking'

r = requests.get(url)
html = r.text

soup = BeautifulSoup(html)
table = soup.find('table', {"class": "ranking"})
rows = table.find_all('tr')
data = []
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

france = pd.DataFrame(data, columns=['Rank', 'Club', 'Elo', 'Last Match', 'Coach'])

# %%
for i in range(21,40):
    france = france.drop(i)

# %%
france
# Out:
#    Rank            Club   Elo  Last Match  \
# 0     1      7 Paris SG  1896  2020-03-11
# 1     2         48 Lyon  1694  2020-03-08
# 2     3    53 Marseille  1679  2020-03-06
# 3     4        59 Lille  1662  2020-03-08
# 4     5       67 Rennes  1646  2020-03-08
# 5     6  83 Montpellier  1611  2020-03-08
# 6     7        91 Reims  1605  2020-03-07
# 7     8         92 Nice  1605  2020-03-07
# 8     9        Bordeaux  1587  2020-03-08
# 9    10          Monaco  1587  2020-03-07
# 10   11      Strasbourg  1578  2020-02-29
# 11   12          Nantes  1569  2020-03-07
# 12   13          Angers  1569  2020-03-07
# 13   14   Saint-Étienne  1550  2020-03-08
# 14   15            Metz  1546  2020-03-07
# 15   16           Nîmes  1536  2020-03-07
# 16   17           Brest  1533  2020-03-07
# 17   18           Dijon  1519  2020-03-07
# 18   19          Troyes  1487  2020-03-06
# 19   20          Amiens  1485  2020-03-06
# 20   21            Lens  1478  2020-03-09
#
# ...

# %%
Home_team=input("Enter the Home Team ")
Away_team=input("Enter the Away Team ")
Team1=france[france['Club']==Home_team]['Elo'].values
Team2=france[france['Club']==Away_team]['Elo'].values
team1_elo=int(Team1)+75 #Home Team has advantage
team2_elo=int(Team2)
elo_diff=team1_elo-team2_elo

print("the probability for",Home_team,"to win is: ",prob_of_winning(elo_diff))
print("the probability for",Away_team,"to win is: ",prob_of_winning(-elo_diff))
# Out:
# Enter the Home Team 48 Lyon
# Enter the Away Team 7 Paris SG
# the probability for 48 Lyon to win is:  0.3249597989597013
# the probability for 7 Paris SG to win is:  0.6750402010402987

# %%
##Serie A Italy
import pandas as pd
import requests
from bs4 import BeautifulSoup
#Germany League
url = 'http://clubelo.com/ITA/Ranking'

r = requests.get(url)
html = r.text

soup = BeautifulSoup(html)
table = soup.find('table', {"class": "ranking"})
rows = table.find_all('tr')
data = []
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

italy = pd.DataFrame(data, columns=['Rank', 'Club', 'Elo', 'Last Match', 'Coach'])

# %%
for i in range(21,40):
    italy = italy.drop(i)

# %%
Home_team=input("Enter the Home Team ")
Away_team=input("Enter the Away Team ")
Team1=italy[italy['Club']==Home_team]['Elo'].values
Team2=italy[italy['Club']==Away_team]['Elo'].values
team1_elo=int(Team1)+75 #Home Team has advantage
team2_elo=int(Team2)
elo_diff=team1_elo-team2_elo

print("the probability for",Home_team,"to win is: ",prob_of_winning(elo_diff))
print("the probability for",Away_team,"to win is: ",prob_of_winning(-elo_diff))
# Out:
# Enter the Home Team 9 Juventus
# Enter the Away Team 11 Atalanta
# the probability for 9 Juventus to win is:  0.6280448056219418
# the probability for 11 Atalanta to win is:  0.3719551943780582

# %%
##Erdevesie Netherlands League
import pandas as pd
import requests
from bs4 import BeautifulSoup
#Germany League
url = 'http://clubelo.com/NED/Ranking'

r = requests.get(url)
html = r.text

soup = BeautifulSoup(html)
table = soup.find('table', {"class": "ranking"})
rows = table.find_all('tr')
data = []
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

holland = pd.DataFrame(data, columns=['Rank', 'Club', 'Elo', 'Last Match', 'Coach'])

# %%
Home_team=input("Enter the Home Team ")
Away_team=input("Enter the Away Team ")
Team1=holland[holland['Club']==Home_team]['Elo'].values
Team2=holland[holland['Club']==Away_team]['Elo'].values
team1_elo=int(Team1)+75 #Home Team has advantage
team2_elo=int(Team2)
elo_diff=team1_elo-team2_elo

print("the probability for",Home_team,"to win is: ",prob_of_winning(elo_diff))
print("the probability for",Away_team,"to win is: ",prob_of_winning(-elo_diff))
# Out:
# Enter the Home Team Twente
# Enter the Away Team 21 Ajax
# the probability for Twente to win is:  0.12129504878814854
# the probability for 21 Ajax to win is:  0.8787049512118514
